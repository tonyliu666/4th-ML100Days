# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    
    """
    mse=sum((y-yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 240.496
# The Mean absolute error is 12.450

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# # [作業2----Answer]

# %% [markdown]
# 1.我選的資料是https://www.kaggle.com/c/digit-recognizer/overview
# ，這組資料是蒐集許多筆的手寫數字(mnist)的資料，因為它對於剛接觸電腦視覺的新手來說是一個很好練習的一份資料集，可以透過cnn堪稱最基礎的神經網路模型去做辨別人類手寫排出來的數字圖形
#
# 2.資料是從http://yann.lecun.com/exdb/mnist/ ，由Yann LeCun、Corinnaa Cortes,Chtistopher J.C Burges所提供，其中所有的數字資料照片均為手寫且拍照得到的資料(有60000個examples，其中10000個是測試資料
#
# 3.所有的圖片資料是以0~255的pixel灰階所構成的圖案，然後每筆資料裡面有兩份data，一份是手寫數字的iamge，另一份是每個image代表的數字(label)，而image是由numpy的ndarray所組成，然後label就是int(0~9)代表的就是0~9的各個數字
#
# 4.除了前面所提到的neural network的方法以外，也可以用其他的分類方法(classification)像是SVM或是K-nearest neighbors...等，然後當所有的手寫資料都分類完畢以後，可以得到的是每種的分類方法它們個別的evaluation score是多少，根據測試集中判別正確的數量跟全部的測試集的比例為多少，就可以去判斷一個classifiction model對這個手寫數字資料的分類好不好

# %% [markdown]
# # [作業3----Answer]

# %% [markdown]
# 1.核心問題為當一個車隊在一個城市裡面，總是會出現載客載不到的狀況而且要持續去在城市裡搜尋有沒有需要載客的，這樣會出現隱藏成本---汽油的使用量增加，所以如何去減少這個多餘的里程數是可以好好思考的問題。我認為能夠有效提升業績的辦法可以透過gps的定位方式得知哪一個路段哪一個時段下的客戶需求量比較大，因此蒐集大量每個時段下的路況人數資料能夠幫助車隊去知道在哪個時間下須要去哪個路段會比較容易載到客人，這樣或許可以有效提升業績
#
# 2.資料可以透過車隊每日的載客分布得知在哪些地方的載客量會比較大，資料的收集方式可以參照uber(app)的叫車模式，知道乘客的叫車地點並且每筆乘客的叫車資訊可以在每一次叫車的過程中存入資料庫中，當收集到某一定量的數據時，就可以做一次數據分析，這些資料可以有效的追蹤乘客喜好的搭車地點，以便車隊去在該時段去該路段等候載客。
#
# 3.所蒐集的資料均為影像image(jpg、png...等)
#
# 4.問題的評估可以利用實際上的汽油的支出成本與先前的汽油支出成本(在尚未有資料分析之前)做過衡量評估，如果有大幅降低成本，就可以說這次的資料分析是對於問題是有幫助的
